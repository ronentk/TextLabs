# %%
import sys
from os.path import join as pjoin
import tw_textlabs
from tw_textlabs.challenges import lab_game
from tw_textlabs.generator.lab_game import LabGameOptions
from tw_textlabs.generator.process_graph import ProcessGraph
from tw_textlabs.utils import quest_gen_logger

# %%
game_name = 'lab-game'
try:
    # Set lab game creation parameters
    level = 21
    seed = 1554442
    lab_game_options = LabGameOptions()
    lab_game_options.max_quest_length = 60
    lab_game_options.quest_gen_options.max_steps = 1500
    lab_game_options.seeds = seed
    
    # Set surface generation automatically according to game difficulty
    lab_game_options.surface_gen_options.set_difficulty_mode(mode)
    
    # make the game
    game = lab_game.make_game_from_level(level, lab_game_options)
    quest = game.quests[0]
    quest_gen_logger.info("Quest surface is: %s" % (quest.desc))

    # compile it
    lab_game_options.path = pjoin("gen_games", game.metadata["uuid"] + ".ulx")
    lab_game_options.force_compile = True
    game_file = tw_textlabs.generator.compile_game(game, lab_game_options)
    print("*** Game created: {}".format(game_file))
    
except Exception as e:
    print("Failed to generate game from seed %d, error: %s" % (seed, str(e)))
# Out:
# 2019-04-04 14:22:49,429 | INFO : Searching for quest satisfying constraints...
# 2019-04-04 14:22:50,954 | INFO : Found solution!
# 2019-04-04 14:22:50,961 | INFO : Found quest: [take(mdsc_0), dlink(mdsc_0,m_1), take(mdsc_1), dlink(mdsc_1,m_1), take(mdsc_2), dlink(mdsc_2,m_2), take(mdsc_3), dlink(mdsc_3,m_2), take(mdsc_4), dlink(mdsc_4,m_3), take(mdsc_5), dlink(mdsc_5,m_3), take(odsc_0), dlink(odsc_0,tlq_op_0), take(odsc_1), dlink(odsc_1,tlq_op_0), take(odsc_2), dlink(odsc_2,tlq_op_1), take(odsc_3), dlink(odsc_3,tlq_op_2), take(odsc_4), dlink(odsc_4,tlq_op_2), take(odsc_5), dlink(odsc_5,tlq_op_2), take(odsc_6), dlink(odsc_6,tlq_op_3), take(m_3), op_ia_assign(m_3,tlq_op_4), op_run(tlq_op_4), take(m_1), op_ia_assign(m_1,tlq_op_0), op_run(tlq_op_0), take(m_0), op_ia_assign(m_0,tlq_op_1), op_run(tlq_op_1), op_o_obtain(tlq_op_4), take(m_2), op_o_obtain(tlq_op_0), op_ia_assign(m_2,tlq_op_2), op_ia_assign(m_3,tlq_op_2), op_ia_assign(m_1,tlq_op_2), op_run(tlq_op_2), op_o_obtain(tlq_op_2), op_ia_assign(mx_2,tlq_op_3), op_o_obtain(tlq_op_1), op_ia_assign(m_0,tlq_op_3), op_run(tlq_op_3), op_o_obtain(tlq_op_3)]
# 2019-04-04 14:22:50,975 | INFO : Quest surface is: The starting materials are ge, mn, na and ni. To start, sinter (op1) ni. After that, describe op4 with opdesc11. Following that, describe op7 with opdesc2, opdesc10 and opdesc9. Next, describe op1 with opdesc1. Following that, describe op2 with opdesc3 and opdesc7. After that, describe na with matdesc4 and matdesc9. Next, rinse (op5) na. Following that, describe mn with matdesc10 and matdesc12. Next, describe ge with matdesc8 and matdesc7. In the next stage, finely grind (op2) ge. In the next stage, compact (op7) mn, na and ge. To finish, arc-melt (op4) the result obtained by op7 and ni.
# *** Game created: gen_games/tw-lab_game-66Ijv-lab-eXO-leebHjMac6vkhjjR.ulx

# %%
# Draw material synthesis quest (game solution)
pg = ProcessGraph()
pg.from_tw_actions(quest.actions)
pg.draw()

# %%
env = tw_textlabs.play(lab_game_options.path)
# Out:
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# The starting materials are ge, mn, na and ni. To start, sinter (op1) ni. After
# that, describe op4 with opdesc11. Following that, describe op7 with opdesc2,
# opdesc10 and opdesc9. Next, describe op1 with opdesc1. Following that, describe
# op2 with opdesc3 and opdesc7. After that, describe na with matdesc4 and
# matdesc9. Next, rinse (op5) na. Following that, describe mn with matdesc10 and
# matdesc12. Next, describe ge with matdesc8 and matdesc7. In the next stage,
# finely grind (op2) ge. In the next stage, compact (op7) mn, na and ge. To
# finish, arc-melt (op4) the result obtained by op7 and ni.
#
# -= Lab =-
# The lab is a magical place where you'll learn materials synthesis
#
# There is a ni, a ge, a mn, a na, a matdesc8, a matdesc7, a matdesc10, a
# matdesc12, a matdesc4, a matdesc9, an opdesc3, an opdesc7, an opdesc1, an
# opdesc2, an opdesc10, an opdesc9, an opdesc11, an op2, an op1, an op7, an op4
# and an op5 on the floor.
#
# Done after 0 steps. Score 0/1.
